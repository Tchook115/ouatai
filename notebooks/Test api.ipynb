# %%
import requests
from PIL import Image
import ast

# %%
message = {'message' : 'draw me 4 small blue bulldozers in the bottom'}
url = 'http://127.0.0.1:8000/'
response = requests.get(url, params=message)

# %%
response
# Out:
# <Response [200]>

# %%
image_data = response.content
image = Image.frombytes('RGBA', (2560, 1600),image_data)
image
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4577/3491328232.py in <module>
#       1 image_data = response.content
# ----> 2 image = Image.frombytes('RGBA', (2560, 1600),image_data)
#       3 image
#
# ~/.pyenv/versions/3.8.6/envs/ouatai/lib/python3.8/site-packages/PIL/Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2733
#    2734     im = new(mode, size)
# -> 2735     im.frombytes(data, decoder_name, args)
#    2736     return im
#    2737
#
# ~/.pyenv/versions/3.8.6/envs/ouatai/lib/python3.8/site-packages/PIL/Image.py in frombytes(self, data, decoder_name, *args)
#     808
#     809         if s[0] >= 0:
# --> 810             raise ValueError("not enough image data")
#     811         if s[1] != 0:
#     812             raise ValueError("cannot decode image data")
#
# ValueError: not enough image data

# %%
from PIL import Image
import requests
message = {'message' : 'draw me a cat'}
url = 'http://127.0.0.1:8000/'

response = requests.get(url, params=message)

# size_image = eval(response.headers['size_image'])
# coordinates = eval(response.headers['coordinates'])
size_image = (2560, 1600)
image_data = response.content
image = Image.frombytes('RGBA', size_image,image_data)
image
# Out:
# <PIL.Image.Image image mode=RGBA size=2560x1600 at 0x7F12F80A2F40>

# %%
message = {'message' : 'help'}
url = 'http://127.0.0.1:8000/'

response = requests.get(url, params=message)
print(type(response.content))
# Out:
# <class 'bytes'>

# %%
print(eval(response.content.decode("utf-8"))['text'])
# Out:
# For your drawing, you can choose a category of words, the color, the size, the number of elements, the vertical position and the horizontal position.
#  Get more help by typing :
#  1) category
#  2) color
#  3) size
#  4) vertical position
#  5) horizontal position

# %%
def calque_merger(current_scene, new_scene):
    final1 = Image.new("RGBA", current_scene.size)
    final1.paste(current_scene, (0, 0), current_scene)
    final1.paste(new_scene, (0, 0), new_scene)
    return final1

# %%
from PIL import Image
import requests
message = {'message' : 'draw me a big cat in the top center'}
url = 'http://127.0.0.1:8000/'

response = requests.get(url, params=message)

# size_image = eval(response.headers['size_image'])
# coordinates = eval(response.headers['coordinates'])
size_image = (2560, 1600)
image_data = response.content
image1 = Image.frombytes('RGBA', size_image,image_data)
image1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4577/108367776.py in <module>
#      10 size_image = (2560, 1600)
#      11 image_data = response.content
# ---> 12 image1 = Image.frombytes('RGBA', size_image,image_data)
#      13 image1
#
# ~/.pyenv/versions/3.8.6/envs/ouatai/lib/python3.8/site-packages/PIL/Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2733
#    2734     im = new(mode, size)
# -> 2735     im.frombytes(data, decoder_name, args)
#    2736     return im
#    2737
#
# ~/.pyenv/versions/3.8.6/envs/ouatai/lib/python3.8/site-packages/PIL/Image.py in frombytes(self, data, decoder_name, *args)
#     808
#     809         if s[0] >= 0:
# --> 810             raise ValueError("not enough image data")
#     811         if s[1] != 0:
#     812             raise ValueError("cannot decode image data")
#
# ValueError: not enough image data

# %%
print(eval(response.content.decode("utf-8"))['text'])

# %%
image1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4577/159156823.py in <module>
# ----> 1 image1
#
# NameError: name 'image1' is not defined

# %%
from PIL import Image
import requests
message = {'message' : 'draw me a big angel in the top center'}
url = 'http://127.0.0.1:8000/'

response = requests.get(url, params=message)

# size_image = eval(response.headers['size_image'])
# coordinates = eval(response.headers['coordinates'])
size_image = (2560, 1600)
image_data = response.content
image2 = Image.frombytes('RGBA', size_image,image_data)
image2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8900/2846057177.py in <module>
#      10 size_image = (2560, 1600)
#      11 image_data = response.content
# ---> 12 image2 = Image.frombytes('RGBA', size_image,image_data)
#      13 image2
#
# ~/.pyenv/versions/3.8.6/envs/ouatai/lib/python3.8/site-packages/PIL/Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2733
#    2734     im = new(mode, size)
# -> 2735     im.frombytes(data, decoder_name, args)
#    2736     return im
#    2737
#
# ~/.pyenv/versions/3.8.6/envs/ouatai/lib/python3.8/site-packages/PIL/Image.py in frombytes(self, data, decoder_name, *args)
#     808
#     809         if s[0] >= 0:
# --> 810             raise ValueError("not enough image data")
#     811         if s[1] != 0:
#     812             raise ValueError("cannot decode image data")
#
# ValueError: not enough image data

# %%
calque_merger(image1, image2)
